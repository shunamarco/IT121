# %% [markdown]
# <a href="https://colab.research.google.com/github/shunamarco/IT121/blob/main/Lab_Act(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
fullname = "John Doe"
age = 22
height = 1.75
currently_working = False


print("Fullname:", fullname)
print(type(fullname))

print("\nAge:", age)
print(type(age))

print("\nHeight in meters:", height)
print(type(height))

print("\nCurrently working?", currently_working)
print(type(currently_working))
# Out:
# Fullname: John Doe
# <class 'str'>
#
# Age: 22
# <class 'int'>
#
# Height in meters: 1.75
# <class 'float'>
#
# Currently working? False
# <class 'bool'>

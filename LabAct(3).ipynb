# %% [markdown]
# <a href="https://colab.research.google.com/github/shunamarco/IT121/blob/main/LabAct(3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input("Enter your name: ")
age = int(input("Enter your age: "))


print("Hello,", name + "!")
print("You are", age, "years old.")
# Out:
# Enter your name: Celeste
# Enter your age: 25
# Hello, Celeste!
# You are 25 years old.

# %% [markdown]
# <a href="https://colab.research.google.com/github/shunamarco/IT121/blob/main/Assignment(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
score = 100

if score >= 75:
    print("Passed")
else:
    print("Failed")
# Out:
# Passed

# %%
score = 60

if score >= 75:
    print("Passed")
else:
    print("Failed")
# Out:
# Failed
